# %%
import os
import rootutils
root = rootutils.setup_root(os.getcwd(), dotenv=True, pythonpath=True, cwd=False)

# %%
import h5py

# Open the HDF5 file
file_path = os.path.join(root, "data", "L1Ntuple_82.h5")
# file_path = os.path.join(root, "data", "links.h5")
with h5py.File(file_path, "r") as f:
    print("Keys in the HDF5 file:", list(f.keys()))
    
    dataset_name = "jets"
    data = f[dataset_name][()]
    print(f"Shape of '{dataset_name}' dataset:", data.shape)
# Out:
# Keys in the HDF5 file: ['ET', 'FET', 'FHT', 'HT', 'L1_DoubleEG8er2p5_HTT300er', 'L1_DoubleEG8er2p5_HTT320er', 'L1_DoubleEG8er2p5_HTT340er', 'L1_DoubleEG_25_12_er2p5', 'L1_DoubleEG_25_14_er2p5', 'L1_DoubleEG_27_14_er2p5', 'L1_DoubleEG_LooseIso18_LooseIso12_er1p5', 'L1_DoubleEG_LooseIso20_LooseIso12_er1p5', 'L1_DoubleEG_LooseIso22_12_er2p5', 'L1_DoubleEG_LooseIso22_LooseIso12_er1p5', 'L1_DoubleEG_LooseIso25_12_er2p5', 'L1_DoubleEG_LooseIso25_LooseIso12_er1p5', 'L1_DoubleIsoTau26er2p1_Jet55_RmOvlp_dR0p5', 'L1_DoubleIsoTau26er2p1_Jet70_RmOvlp_dR0p5', 'L1_DoubleIsoTau34er2p1', 'L1_DoubleIsoTau35er2p1', 'L1_DoubleIsoTau36er2p1', 'L1_DoubleJet112er2p3_dEta_Max1p6', 'L1_DoubleJet150er2p5', 'L1_DoubleJet30er2p5_Mass_Min300_dEta_Max1p5', 'L1_DoubleJet30er2p5_Mass_Min330_dEta_Max1p5', 'L1_DoubleJet30er2p5_Mass_Min360_dEta_Max1p5', 'L1_DoubleJet35_Mass_Min450_IsoTau45er2p1_RmOvlp_dR0p5', 'L1_DoubleJet40_Mass_Min450_LooseIsoEG15er2p1_RmOvlp_dR0p2', 'L1_DoubleJet45_Mass_Min450_IsoTau45er2p1_RmOvlp
# ...

# %% [markdown]
# # DataLoader
#
# ## Loading the data

# %%
from typing import Optional
import hydra
from omegaconf import DictConfig

# %%
@hydra.main(version_base="1.3", config_path="../configs", config_name="debug.yaml")
def load_config_test(cfg: DictConfig) -> Optional[float]:
    """Main entry point for training.

    :param cfg: DictConfig configuration composed by Hydra.
    :return: Optional[float] with optimized metric value.
    """
    
    print("This is the configuration:")
    print(cfg)
    return

load_config_test()
# Out:
# usage: ipykernel_launcher.py [--help] [--hydra-help] [--version]
#                              [--cfg {job,hydra,all}] [--resolve]
#                              [--package PACKAGE] [--run] [--multirun]
#                              [--shell-completion] [--config-path CONFIG_PATH]
#                              [--config-name CONFIG_NAME]
#                              [--config-dir CONFIG_DIR]
#                              [--experimental-rerun EXPERIMENTAL_RERUN]
#                              [--info [{all,config,defaults,defaults-tree,plugins,searchpath}]]
#                              [overrides ...]
# ipykernel_launcher.py: error: unrecognized arguments: --f=c:\Users\victo\AppData\Roaming\jupyter\runtime\kernel-v3fdf9aea1a54c0cddb965dc927742fc2dab88c04b.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
data_bkg = data_util._read.get_data_background(config=config_bkg)
data_sig = data_util._read.get_data_signal(config=config_sig)
